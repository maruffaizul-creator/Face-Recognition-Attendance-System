# %% [markdown]
# # Smart Attendance System Using Face Recognition
#
# ## Objective
# To develop an AI-based attendance system that automatically identifies students using facial recognition and records attendance automatically.
#
# ## Technologies Used
# - Python
# - OpenCV
# - NumPy
# - Scikit-Learn (KNN)
# - Pandas
# - Streamlit
#
# ## Dataset Information
# - Total Face Samples: 150
# - Number of Students: 3
# - Samples per Student: 50
#
# Students:
# 1. Huzaifa Rashid
# 2. Ahad Sultan
# 3. Faizan Ranjha

# %% [markdown]
# # Project Overview
#
# This project is an AI-based attendance management system that uses facial recognition to identify students and mark attendance automatically.
#
# ## Working Process
#
# 1. Capture face images using a webcam.
# 2. Detect faces using Haar Cascade Classifier.
# 3. Store face data and student names.
# 4. Train a K-Nearest Neighbors (KNN) classifier.
# 5. Recognize faces in real-time.
# 6. Mark attendance in a CSV file automatically.

# %% [markdown]
# # Dataset Description
#
# The dataset contains facial images of three students.
#
# - Huzaifa Rashid: 50 samples
# - Ahad Sultan: 50 samples
# - Faizan Ranjha: 50 samples
#
# Total Samples: 150
#
# Each image is resized to 50 × 50 pixels and converted into a numerical feature vector before training the KNN classifier.

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\DELL\OneDrive\Desktop

# %%
import os

for item in os.listdir():
    print(item)
# Out:
# 10TH.pdf
# 30kb.jpg
# A023166923065_SkFaijuluddim.pdf
# ADA.FINAL.docx
# ADA.FINAL.pdf
# ADDRESS.jpg
# admit.pdf
# ADRESSPDF.pdf
# AMITY PFP.jpg
# as1.pdf
# as2.pdf
# BORNSOCIAL.pdf
# bsfile.docx
# bsfile.FAIZ.docx
# c++pdf.pdf
# certificate.completion.pdf
# changesign.docx
# chomu.jpg
# CourseCurriculum (1).pdf
# cuet photo.jpg
# cuet sign.jpg
# cuetsign2.jpg
# cuetsign3.jpg
# dc.png
# deco.done.docx
# deco.edit.pdf
# deco.Final .pdf
# deco.Final.docx
# deco.main.docx
# deco.main.pdf
# deco.ppt.compressed.pptx
# deco.ppt.pdf
# deco.ppt.pptx
# decoremainingfile.pdf
# desktop.ini
# Discord.lnk
# DPSA.docx
# DPSA.pdf
# DS File(Index and Cover Page) SHAHID.docx
# DS File(Index and Cover Page).docx
# DSA PRACTICAL FILE.docx
# dsasyllabus.pdf
# edititing.pdf
# EN.FINAL.docx
# EN.FINAL.PDF
# ENFILE.FAIZ.docx
# ENFILE.pdf
# faiz.zip
# FAIZCV.pdf
# faizsign.jpeg
# faizul..jpg
# faizul.wpr1.docx
# faizul.wpr1pdf.pdf
# faizuldecoredocx.docx
# FSPlogin.pdf
# FSPSIGNUPSS.pdf
# FUCKYOU - Copy.py
# ...

# %%
import os

for item in os.listdir(r"C:\Users\DELL\OneDrive\Desktop"):
    print(item)
# Out:
# 10TH.pdf
# 30kb.jpg
# A023166923065_SkFaijuluddim.pdf
# ADA.FINAL.docx
# ADA.FINAL.pdf
# ADDRESS.jpg
# admit.pdf
# ADRESSPDF.pdf
# AMITY PFP.jpg
# as1.pdf
# as2.pdf
# BORNSOCIAL.pdf
# bsfile.docx
# bsfile.FAIZ.docx
# c++pdf.pdf
# certificate.completion.pdf
# changesign.docx
# chomu.jpg
# CourseCurriculum (1).pdf
# cuet photo.jpg
# cuet sign.jpg
# cuetsign2.jpg
# cuetsign3.jpg
# dc.png
# deco.done.docx
# deco.edit.pdf
# deco.Final .pdf
# deco.Final.docx
# deco.main.docx
# deco.main.pdf
# deco.ppt.compressed.pptx
# deco.ppt.pdf
# deco.ppt.pptx
# decoremainingfile.pdf
# desktop.ini
# Discord.lnk
# DPSA.docx
# DPSA.pdf
# DS File(Index and Cover Page) SHAHID.docx
# DS File(Index and Cover Page).docx
# DSA PRACTICAL FILE.docx
# dsasyllabus.pdf
# edititing.pdf
# EN.FINAL.docx
# EN.FINAL.PDF
# ENFILE.FAIZ.docx
# ENFILE.pdf
# faiz.zip
# FAIZCV.pdf
# faizsign.jpeg
# faizul..jpg
# faizul.wpr1.docx
# faizul.wpr1pdf.pdf
# faizuldecoredocx.docx
# FSPlogin.pdf
# FSPSIGNUPSS.pdf
# FUCKYOU - Copy.py
# ...

# %%
import os

print(os.path.abspath("name.pkl"))
print(os.path.exists("name.pkl"))
# Out:
# c:\Users\DELL\OneDrive\Desktop\name.pkl
# False

# %%
import os

print(os.path.exists("FACE-RECOGNITION-ATTENDANCE-SYSTEM/name.pkl"))
# Out:
# False

# %%
import os

for item in os.listdir():
    if "FACE" in item.upper():
        print(item)
# Out:
# USER INTERFACE.mp4

# %%
import os

for root, dirs, files in os.walk(r"C:\Users\DELL\OneDrive\Desktop"):
    if "name.pkl" in files:
        print(root)

# %%
import os

print("Current folder:")
print(os.getcwd())

print("\nFiles here:")
print(os.listdir())
# Out:
# Current folder:
# c:\Users\DELL\OneDrive\Desktop
#
# Files here:
# ...

# %%
import os

print(os.path.abspath("app.py"))
print(os.path.abspath("name.pkl"))
# Out:
# c:\Users\DELL\OneDrive\Desktop\app.py
# c:\Users\DELL\OneDrive\Desktop\name.pkl

# %%
import os

print(os.path.exists("app.py"))
print(os.path.exists("name.pkl"))
# Out:
# False
# False

# %%
import os
os.chdir(r"C:\Users\DELL\OneDrive\Documents\Face-Recognition-Attendance-System")

print(os.getcwd())
print(os.path.exists("name.pkl"))
# Out:
# C:\Users\DELL\OneDrive\Documents\Face-Recognition-Attendance-System
# True

# %%
import pickle

with open("name.pkl", "rb") as f:
    names = pickle.load(f)

print("Loaded successfully!")
print(type(names))
print(len(names))
# Out:
# Loaded successfully!
# <class 'list'>
# 150

# %%
import pickle

with open("faces_data.pkl", "rb") as f:
    faces = pickle.load(f)

print(type(faces))
print(faces.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 4
#       1 import pickle
#       3 with open("faces_data.pkl", "rb") as f:
# ----> 4     faces = pickle.load(f)
#       6 print(type(faces))
#       7 print(faces.shape)
#
# ModuleNotFoundError: No module named 'numpy'
